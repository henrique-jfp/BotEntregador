# %%
# Investigating Session Call structure in bot_multidelivery/session.py
# The file defines SessionManager with methods: _auto_save, create_new_session, get_session, get_current_session, list_sessions.
# The `_auto_save` method calls `session_store.save_session(session)`.
# However, the public method `save_session(session)` is MISSING from SessionManager class. 
# Routers (like romaneio.py) call `session_manager.save_session(session)`.

# Fix: Add `save_session` alias to `_auto_save` in SessionManager.

# Also, I will check bot_multidelivery/handlers/common.py to see the text for admin start button.

# %%
# We are creating a temporary notebook to confirm the bug with parser types manually if needed, 
# but the code analysis is strong enough.
# Proceeding with direct file edits.
